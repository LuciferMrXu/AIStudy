# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression,Ridge   # lr模型最适合处理稀疏矩阵
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv("./datas/zhengqi_train.txt",sep="\t")
x = df.drop(['target'],1)
y = df['target']
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75,test_size=0.25)
df.head()
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360 -0.436 -2.114
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  0.332 -2.114
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  0.396 -2.114
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  0.403 -2.114
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  0.314 -2.114
#
#     ...      V29    V30    V31    V32    V33    V34    V35    V36    V37  \
# 0   ...    0.136  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1   ...   -0.128  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2   ...   -0.009  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3   ...    0.015  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4   ...    0.183  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
#
# ...

# %%
#构建Stacking模型（分类用gbdt+lr，回归用gbdt+ridge）
gbdt = GradientBoostingRegressor(learning_rate=0.1,
                                 n_estimators=180,
                                 subsample=1)

gbdt.fit(x_train, y_train)
y_test_pred = gbdt.predict(x_test)
y_train_pred = gbdt.predict(x_train)

print("train mse",mean_squared_error(y_train,y_train_pred))
print("test mse", mean_squared_error(y_test,y_test_pred))
# Out:
# train mse 0.05048249071873306
# test mse 0.1044748934043038

# %%
# 叶编码处理
x_train_leaf=gbdt.apply(x_train)   # 相获取数据分别落在对应决策树的哪片叶子上
x_test_leaf=gbdt.apply(x_test)
print(x_train.head(2))
print(x_train_leaf.shape)
x_train_leaf
# Out:
#          V0     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 1602  1.161  0.844 -0.277  0.122  0.666 -0.593  0.378  0.491  1.207  0.042
# 2374  0.798  0.722  0.646 -0.081  0.063 -0.421  0.969  0.768  0.997  0.042
#
#       ...      V28    V29    V30    V31    V32    V33   V34    V35    V36  \
# 1602  ...   -0.454  0.803  1.343  0.648 -0.346 -0.613 -0.29  0.364  0.266
# 2374  ...    0.400 -0.058  0.958  0.797  0.108  0.419  0.16 -0.943  0.717
#
#         V37
# 1602 -0.040
# 2374 -0.108
#
# [2 rows x 38 columns]
# (2166, 180)
# array([[14., 14., 14., ...,  7., 14., 13.],
#        [13., 13., 13., ...,  7., 14., 13.],
#        [13., 13., 13., ...,  6., 14., 13.],
#        ...,
#        [13., 13., 13., ...,  6., 14., 13.],
#        [ 4.,  4.,  4., ...,  7., 14., 13.],
#        [ 6.,  7.,  7., ...,  7., 14., 13.]])

# %%
# 做onehot扩展维度
oh=OneHotEncoder(categories='auto')
x_train_leaf=oh.fit_transform(x_train_leaf)
x_test_leaf=oh.transform(x_test_leaf)

# %%
# GBDT+ridge
# lr=LogisticRegression(C=1)
lr=Ridge(alpha=7)
lr.fit(x_train_leaf,y_train)
y_test_pred = lr.predict(x_test_leaf)
y_train_pred = lr.predict(x_train_leaf)

print("train mse",mean_squared_error(y_train,y_train_pred))
print("test mse", mean_squared_error(y_test,y_test_pred))
# Out:
# train mse 0.025086272648020422
# test mse 0.10483204091707551
