# %%
import tensorflow as tf

v1 = tf.Variable(tf.random_normal([1,2]), name="v1")
v2 = tf.Variable(tf.random_normal([2,3]), name="v2")
init_op = tf.global_variables_initializer()
saver = tf.train.Saver()
with tf.Session() as sess:
    sess.run(init_op)
    print ("V1:",sess.run(v1))  
    print ("V2:",sess.run(v2))
    saver_path = saver.save(sess, "save/model.ckpt")
    print ("Model saved in file: ", saver_path)

# %%
import tensorflow as tf
v1 = tf.Variable(tf.random_normal([1,2]), name="v1")
v2 = tf.Variable(tf.random_normal([2,3]), name="v2")
saver = tf.train.Saver()

with tf.Session() as sess:
    saver.restore(sess, "save/model.ckpt")
    print ("V1:",sess.run(v1))  
    print ("V2:",sess.run(v2))
    print ("Model restored")
# Out:
# INFO:tensorflow:Restoring parameters from save/model.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# NotFoundError: Key v1_1 not found in checkpoint
# 	 [[{{node save_1/RestoreV2}} = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
# 	 [[{{node save_1/RestoreV2/_5}} = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_10_save_1/RestoreV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1545         sess.run(self.saver_def.restore_op_name,
# -> 1546                  {self.saver_def.filename_tensor_name: save_path})
#    1547     except errors.NotFoundError as err:
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#
# NotFoundError: Key v1_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-d652da9334f1>:4)  = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
# 	 [[{{node save_1/RestoreV2/_5}} = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_10_save_1/RestoreV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "G:\py\anaconda64\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "G:\py\anaconda64\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "G:\py\anaconda64\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "G:\py\anaconda64\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "G:\py\anaconda64\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "G:\py\anaconda64\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "G:\py\anaconda64\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "G:\py\anaconda64\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "G:\py\anaconda64\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 2843, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 2869, in _run_cell
#     return runner(coro)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 3044, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 3209, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-d652da9334f1>", line 4, in <module>
#     saver = tf.train.Saver()
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 1102, in __init__
#     self.build()
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 1114, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 1151, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 795, in _build_internal
#     restore_sequentially, reshape)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 406, in _AddRestoreOps
#     restore_sequentially)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 862, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1466, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\util\deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): Key v1_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-d652da9334f1>:4)  = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
# 	 [[{{node save_1/RestoreV2/_5}} = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_10_save_1/RestoreV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1555       try:
# -> 1556         names_to_keys = object_graph_key_mapping(save_path)
#    1557       except errors.NotFoundError:
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py in object_graph_key_mapping(checkpoint_path)
#    1829   object_graph_string = reader.get_tensor(
# -> 1830       checkpointable.OBJECT_GRAPH_PROTO_KEY)
#    1831   object_graph_proto = (
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in get_tensor(self, tensor_str)
#     370         return CheckpointReader_GetTensor(self, compat.as_bytes(tensor_str),
# --> 371                                           status)
#     372
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-2-d652da9334f1> in <module>
#       5
#       6 with tf.Session() as sess:
# ----> 7     saver.restore(sess, "save/model.ckpt")
#       8     print ("V1:",sess.run(v1))
#       9     print ("V2:",sess.run(v2))
#
# G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1560         # a helpful message (b/110263146)
#    1561         raise _wrap_restore_error_with_msg(
# -> 1562             err, "a Variable name or other graph key that is missing")
#    1563
#    1564       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key v1_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-d652da9334f1>:4)  = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
# 	 [[{{node save_1/RestoreV2/_5}} = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_10_save_1/RestoreV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "G:\py\anaconda64\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "G:\py\anaconda64\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "G:\py\anaconda64\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "G:\py\anaconda64\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "G:\py\anaconda64\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "G:\py\anaconda64\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "G:\py\anaconda64\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "G:\py\anaconda64\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "G:\py\anaconda64\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "G:\py\anaconda64\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "G:\py\anaconda64\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 2843, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 2869, in _run_cell
#     return runner(coro)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 3044, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 3209, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "G:\py\anaconda64\lib\site-packages\IPython\core\interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-d652da9334f1>", line 4, in <module>
#     saver = tf.train.Saver()
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 1102, in __init__
#     self.build()
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 1114, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 1151, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 795, in _build_internal
#     restore_sequentially, reshape)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 406, in _AddRestoreOps
#     restore_sequentially)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\training\saver.py", line 862, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1466, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\util\deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "G:\py\anaconda64\lib\site-packages\tensorflow\python\framework\ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key v1_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-d652da9334f1>:4)  = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
# 	 [[{{node save_1/RestoreV2/_5}} = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_10_save_1/RestoreV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
